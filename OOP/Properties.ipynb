# %%
class Product:
    def __init__(self, name, price):
        self._name = name
        if price < 0:
            raise ValueError("Price cannot be negative")
        else:
          self._price = price

    @property
    def name(self):
        return self._name

    @name.setter
    def name(self, value):
        self._name = value

    @property
    def price(self):
      return self._price


    @price.setter
    def price(self, value):
        if value < 0:
            raise ValueError("Price cannot be negative")
        else:
          self._price = value



    """
    def set_price(self,price):
       if price < 0:
          raise ValueError("Price cannot be negative")
      else:
          self.price = price

    def get_price(self):
       return self.price
    """

# %%
p=Product("apple",10)

# %%
p2=Product("banana",-20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-84c859028f30> in <cell line: 1>()
# ----> 1 p2=Product("banana",-20)
#
# <ipython-input-58-673b7c73eb40> in __init__(self, name, price)
#       3         self._name = name
#       4         if price < 0:
# ----> 5             raise ValueError("Price cannot be negative")
#       6         else:
#       7           self._price = price
#
# ValueError: Price cannot be negative

# %%
p.price
# Out:
# 10

# %%
p.price=20

# %%
p.price
# Out:
# 20

# %%
p.price=-3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-e670fc635d18> in <cell line: 1>()
# ----> 1 p.price=-3
#
# <ipython-input-58-673b7c73eb40> in price(self, value)
#      23     def price(self, value):
#      24         if value < 0:
# ---> 25             raise ValueError("Price cannot be negative")
#      26         else:
#      27           self._price = value
#
# ValueError: Price cannot be negative
