# %%
import re

# %%
sampleText="This is a very long story...."

# %%
pattern="is"
result=re.search(pattern,sampleText)
print(result)
# Out:
# <re.Match object; span=(2, 4), match='is'>

# %%
result.span()
# Out:
# (2, 4)

# %%
result.start()
# Out:
# 2

# %%
result.end()
# Out:
# 4

# %%
re.findall(pattern,sampleText)
# Out:
# ['is', 'is']

# %%
text="x23x34 67 5 592 AB x5 34w516 k347"

# %%
pattern=r"\d\d\d"

# %%
result=re.search(pattern,text)

# %%
print(result)
# Out:
# <re.Match object; span=(12, 15), match='592'>

# %%
result=re.findall(pattern,text)

# %%
print(result)
# Out:
# ['592', '516', '347']

# %%
pattern=r"\d+"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# 23
# 34
# 67
# 5
# 592
# 5
# 34
# 516
# 347

# %%
pattern=r"\d{4}"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())

# %%
pattern=r"\d{2,4}"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# 23
# 34
# 67
# 592
# 34
# 516
# 347

# %%
pattern=r"\d{3,}"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# 592
# 516
# 347

# %%
pattern=r"\d{,3}"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# 23
#
# 34
#
# 67
#
# 5
#
# 592
#
#
#
#
#
# 5
#
# 34
#
# 516
#
#
# 347

# %%
pattern=r"\d.\d"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# 3x3
# 4 6
# 7 5
# 592
# 5 3
# 4w5
# 347

# %%
pattern=r"[a-zA-Z]"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# x
# x
# A
# B
# x
# w
# k

# %%
  pattern=r"\d{,3}|[a-zA-Z]"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# x
# 23
#
# x
# 34
#
# 67
#
# 5
#
# 592
#
#
# A
#
# B
#
#
# x
# 5
#
# 34
#
# w
# 516
#
#
# k
# 347

# %%
pattern=r"\w\w"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# x2
# 3x
# 34
# 67
# 59
# AB
# x5
# 34
# w5
# 16
# k3
# 47

# %%
pattern=r"^x\d"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# x2

# %%
pattern=r"k\d{2,}$"

# %%
matches=re.finditer(pattern,text)

# %%
for m in matches:
    print(m.group())
# Out:
# k347
