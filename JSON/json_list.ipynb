# %%
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
import json

# %% [markdown]
# **JSON STRING**

# %%
data=[
    {"id": 1, "title": "Phone", "price": 10000, "rating": 3.6, "category": "electronics", "color": ["red", "blue"]},
    {"id": 1, "title": "Charger", "price": 20000, "rating": 3.9, "category": "electronics", "color": ["yellow", "green"]}


    ]

# %%
result=json.dumps(data)

# %%
  print(result)
  print(type(result))
# Out:
# [{"id": 1, "title": "Phone", "price": 10000, "rating": 3.6, "category": "electronics", "color": ["red", "blue"]}, {"id": 1, "title": "Charger", "price": 20000, "rating": 3.9, "category": "electronics", "color": ["yellow", "green"]}]
# <class 'str'>

# %%
with open("/gdrive/My Drive/İleriPython/JSON/products.json", "w", encoding="utf-8") as f:
   json.dump(data,f,ensure_ascii=False, indent=2)

# %%
addition_product= {"id": 1, "title": "Laptop", "price": 150000, "rating": 5.6, "category": "electronics", "color": ["cyan", "pink"]}

# %%
with open("/gdrive/My Drive/İleriPython/JSON/products.json", "r") as f:
   products=json.load(f)

# %%
products.append(addition_product)

# %%
with open("/gdrive/My Drive/İleriPython/JSON/products.json", "w", encoding="utf-8") as f:
   json.dump(products,f,ensure_ascii=False, indent=2)
