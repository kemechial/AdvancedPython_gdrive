# %%
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import json

# %% [markdown]
# **JSON STRING**

# %%
data={"id":1,
  "title":"Phone",
  "price":10000,
  "rating":3.6,
  "category":"electronics",
  "color":["red","blue"]
}

# %%
result=json.dumps(data)

# %%
  print(result)
  print(type(result))
# Out:
# {"id": 1, "title": "Phone", "price": 10000, "rating": 3.6, "category": "electronics", "color": ["red", "blue"]}
# <class 'str'>

# %%
with open("/gdrive/My Drive/İleriPython/JSON/product.json", "w") as f:
   json.dump(data,f)
