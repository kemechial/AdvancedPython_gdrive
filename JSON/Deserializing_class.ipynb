# %%
import json

# %%
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
class Product:
    def __init__(self,id,title,price):
        self.id=id
        self.title=title
        self.price=price

# %%
p1=Product(1,"title1",100)

# %%
with open("/gdrive/My Drive/İleriPython/JSON/products_class.json","w") as f:
   # data=json.dump(p1,f) gives error
    data=json.dump(p1.__dict__,f)
