# %%
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
import json

# %%
with open("/gdrive/My Drive/İleriPython/JSON/test.json", "r") as f:
  data=json.load(f)
  print(data)
  print(type(data))
  print(data["title"])
# Out:
# {'id': 1, 'title': 'Phone', 'price': 10000, 'rating': 3.6, 'category': 'electronics', 'color': ['red', 'blue']}
# <class 'dict'>
# Phone

# %% [markdown]
# **JSON STRING**

# %%
data_string="""
      {"id":1,
  "title":"Phone",
  "price":10000,
  "rating":3.6,
  "category":"electronics",
  "color":["red","blue"]
}
"""

# %%
json.loads(data_string)
# Out:
# {'id': 1,
#  'title': 'Phone',
#  'price': 10000,
#  'rating': 3.6,
#  'category': 'electronics',
#  'color': ['red', 'blue']}

# %%
  print(data)
  print(type(data))
  print(data["title"])
# Out:
# {'id': 1, 'title': 'Phone', 'price': 10000, 'rating': 3.6, 'category': 'electronics', 'color': ['red', 'blue']}
# <class 'dict'>
# Phone
