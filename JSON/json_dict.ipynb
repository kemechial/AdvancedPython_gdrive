# %%
from google.colab  import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import json

# %% [markdown]
# **JSON STRING**

# %%
data={
      "1": { "title": "Phone", "price": 10000, "rating": 3.6, "category": "electronics", "color": ["red", "blue"]},
      "2": { "title": "Charger", "price": 20000, "rating": 3.9, "category": "electronics", "color": ["yellow", "green"]}
}

# %%
result=json.dumps(data)

# %%
  print(result)
  print(type(result))
# Out:
# {"1": {"title": "Phone", "price": 10000, "rating": 3.6, "category": "electronics", "color": ["red", "blue"]}, "2": {"title": "Charger", "price": 20000, "rating": 3.9, "category": "electronics", "color": ["yellow", "green"]}}
# <class 'str'>

# %%
with open("/gdrive/My Drive/İleriPython/JSON/products_dict.json", "w", encoding="utf-8") as f:
   json.dump(data,f,ensure_ascii=False, indent=2)

# %%
with open("/gdrive/My Drive/İleriPython/JSON/products_dict.json", "r") as f:
   products=json.load(f)

# %%
print(products["1"])
# Out:
# {'title': 'Phone', 'price': 10000, 'rating': 3.6, 'category': 'electronics', 'color': ['red', 'blue']}

# %%
products.update({"4":{ "title": "Coffee", "price": 205400, "rating": 5.2, "category": "electronics", "color": ["scarlet", "magenta"]}})

# %%
print(products)
# Out:
# {'1': {'title': 'Phone', 'price': 10000, 'rating': 3.6, 'category': 'electronics', 'color': ['red', 'blue']}, '2': {'title': 'Charger', 'price': 20000, 'rating': 3.9, 'category': 'electronics', 'color': ['yellow', 'green']}, '4': {'title': 'Coffee', 'price': 205400, 'rating': 5.2, 'category': 'electronics', 'color': ['scarlet', 'magenta']}}

# %%
with open("/gdrive/My Drive/İleriPython/JSON/products_dict.json", "w", encoding="utf-8") as f:
   json.dump(products,f,ensure_ascii=False, indent=2)
