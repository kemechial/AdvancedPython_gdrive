# %%
products=[{"name":"milk", "price":2000},{"name":"cotton", "price":4000},{"name":"tomato" ,"price":3000}]
prices=[ product["price"] for product in products]
sum(prices)
# Out:
# 9000

# %%
round(1.5)
# Out:
# 2

# %%
round(1.324673)
# Out:
# 1

# %%
round(1.324673,3)
# Out:
# 1.325
