# %%
def square(x):
  return x**2

# %%
list1=[3,4,6,2,7]
list2=list(map(square,list1))
print(list2)
# Out:
# [9, 16, 36, 4, 49]

# %%
list4=list(map(lambda x: x**3, list1))
print(list4)
# Out:
# [27, 64, 216, 8, 343]

# %%
numbers=["1","4","6","7","8"]
list5=list(map(int,numbers))
print(list5)
# Out:
# [1, 4, 6, 7, 8]

# %%
people=[{"name":"jane","surname":"smith"},{"name":"alex","surname":"smith"}]

# %%
list3=list(map(lambda person: person["name"],people))
print(list3)
# Out:
# ['jane', 'alex']
