# %%
list1=[3,5,7,10]
max(list1)
# Out:
# 10

# %%
characters=["a",'e','a',"t","z"]
max(characters)
# Out:
# 'z'

# %%
names=["edward","jack","tommy","klaus","abraham"]
max([len(name) for name in names])
# Out:
# 7

# %%
max(names,key=lambda name:len(name))
# Out:
# 'abraham'

# %%
min(names,key=lambda name:len(name))
# Out:
# 'jack'

# %%
products=[{"name":"butter","price":5000},{"name":"butter","price":2000},{"name":"soap","price":3000}]

# %%
max(products,key = lambda products: products["price"])
# Out:
# {'name': 'butter', 'price': 5000}
