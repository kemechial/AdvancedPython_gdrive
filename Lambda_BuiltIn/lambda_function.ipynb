# %%
(lambda a: a*4)(5)
# Out:
# 20

# %%
func_1=lambda x,y: x*2+y**2
func_1(4,5)
# Out:
# 33

# %%
def create_fun(x):
    return lambda y: x*y

# %%
mul_5=create_fun(5)
mul_4=create_fun(4)

# %%
mul_5(5)
# Out:
# 25

# %%
mul_4(y=9)
# Out:
# 36
