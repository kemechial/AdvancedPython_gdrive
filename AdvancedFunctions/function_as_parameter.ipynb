# %%
def filter2(fn2,list2):
  result=[]
  for item in list2:
    if fn2(item):
      result.append(item)
  return result

# %%
def is_even(item):
  return item%2==0

# %%
def is_positive(item):
  return item>0

# %%
test=[3,5,6,2,6]
print(filter2(is_even,test))
# Out:
# [6, 2, 6]
